# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


# read image
img = cv2.imread('dir.png')
img = cv2.resize(img, (512,512))

# convert image to hsv colorspace
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(hsv)

# threshold saturation image
thresh1 = cv2.threshold(s, 92, 255, cv2.THRESH_BINARY)[1]

# threshold value image and invert
thresh2 = cv2.threshold(v, 128, 255, cv2.THRESH_BINARY)[1]
thresh2 = 255 - thresh2

# combine the two threshold images as a mask
mask = cv2.add(thresh1,thresh2)

# use mask to remove lines in background of input
result = img.copy()
result[mask==0] = (255,255,255)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow( img)
cv2_imshow( s)
cv2_imshow( v)
cv2_imshow( thresh1)
cv2_imshow( thresh2)
cv2_imshow( mask)
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FD86374E2D0>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FD853BBA3D0>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FD853C3DF50>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FD8608CEA50>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FD853BBAFD0>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FD853C3DF50>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FD853BBA3D0>

# %%
rmask = cv2.bitwise_not(mask)
cv2_imshow(rmask)
#plt.imshow(rmask)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FD853C3DDD0>

# %%
img = cv2.imread('teste.jpg')
img = cv2.resize(img,(512,512))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FD4A1E305D0>
